# %%
import pandas as pd

# Load dataset
df = pd.read_excel("ApexPlanet_DataAnalytics_Dataset.xlsx")

# Remove missing values
df = df.dropna()

# Total Sales
total_sales = df["Total_Sales"].sum()

# Total Quantity
total_quantity = df["Quantity"].sum()

# Average Unit Price
average_unit_price = df["Unit_Price"].mean()

# Average Age
average_age = df["Age"].mean()

# Total Customers
total_customers = df["Customer_ID"].nunique()

# Total Orders
total_orders = df["Order_ID"].nunique()

# Sales by Category
sales_by_category = df.groupby("Category")["Total_Sales"].sum()

# Sales by City
sales_by_city = df.groupby("City")["Total_Sales"].sum()

# Sales by Gender
sales_by_gender = df.groupby("Gender")["Total_Sales"].sum()

# Quantity by Product
quantity_by_product = df.groupby("Product")["Quantity"].sum()

# Sales Trend
sales_trend = df.groupby("Order_Date")["Total_Sales"].sum()

# Display Results
print("Total Sales:", total_sales)
print("Total Quantity:", total_quantity)
print("Average Unit Price:", average_unit_price)
print("Average Age:", average_age)
print("Total Customers:", total_customers)
print("Total Orders:", total_orders)

print("\nSales by Category")
print(sales_by_category)

print("\nSales by City")
print(sales_by_city)

print("\nSales by Gender")
print(sales_by_gender)

print("\nQuantity by Product")
print(quantity_by_product)

print("\nSales Trend")
print(sales_trend)
# Out:
# Total Sales: 135593605.08999997
# Total Quantity: 5267
# Average Unit Price: 25587.462692702982
# Average Age: 41.360739979445015
# Total Customers: 922
# Total Orders: 967
#
# Sales by Category
# Category
# Education      24476275.98
# Electronics    49399790.32
# Fashion        19830632.00
# Furniture      20561087.37
# Grocery        21325819.42
# Name: Total_Sales, dtype: float64
#
# Sales by City
# City
# Bengaluru    18751173.20
# Delhi        15932359.80
# Gaya         14380859.39
# Hyderabad    17087958.01
# Kolkata      18327246.57
# Mumbai       18650775.20
# Patna        19124282.19
# Pune         13338950.73
# Name: Total_Sales, dtype: float64
#
# Sales by Gender
# Gender
# Female    65298472.14
# Male      70295132.95
# Name: Total_Sales, dtype: float64
#
# Quantity by Product
# Product
# Book      958
# Chair     817
# Laptop    931
# Mobile    979
# Rice      790
# Shoes     792
# Name: Quantity, dtype: int64
#
# Sales Trend
# Order_Date
# 2025-01-01     23787.60
# 2025-01-04    307641.35
# 2025-01-05    194749.86
# 2025-01-06    721080.92
# 2025-01-07    591822.16
#                 ...
# 2025-12-28    256767.72
# 2025-12-29    270452.40
# 2025-12-30     62518.32
# 2025-12-31    518752.45
# 2026-01-01    809389.99
# Name: Total_Sales, Length: 340, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("ApexPlanet_DataAnalytics_Dataset.xlsx")

sales = df.groupby("Category")["Total_Sales"].sum()

plt.figure(figsize=(6,4))
plt.bar(sales.index, sales.values)
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("ApexPlanet_DataAnalytics_Dataset.xlsx")

sales = df.groupby("Order_Date")["Total_Sales"].sum()

plt.figure(figsize=(8,4))
plt.plot(sales.index, sales.values)
plt.title("Sales Trend")
plt.xlabel("Order Date")
plt.ylabel("Total Sales")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("ApexPlanet_DataAnalytics_Dataset.xlsx")

sales = df.groupby("Category")["Total_Sales"].sum()

plt.figure(figsize=(6,6))
plt.pie(sales.values, labels=sales.index, autopct="%1.1f%%")
plt.title("Sales by Category")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("ApexPlanet_DataAnalytics_Dataset.xlsx")

sales = df.groupby("Gender")["Total_Sales"].sum()

plt.figure(figsize=(6,6))
plt.pie(sales.values, labels=sales.index, autopct="%1.1f%%")
centre_circle = plt.Circle((0,0),0.70,color="white")
plt.gca().add_artist(centre_circle)
plt.title("Sales by Gender")
plt.show()

# %%
# !pip install squarify
import pandas as pd
import matplotlib.pyplot as plt
import squarify

df = pd.read_excel("ApexPlanet_DataAnalytics_Dataset.xlsx")

sales = df.groupby("Product")["Total_Sales"].sum()

plt.figure(figsize=(8,6))
squarify.plot(sizes=sales.values, label=sales.index)
plt.title("Sales by Product")
plt.axis("off")
plt.show()
# Out:
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4
